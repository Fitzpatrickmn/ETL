# %%
import pandas as pd 
import numpy as np
import os

# %%
Original = pd.read_csv("MergedDF_notclean.csv")

# %%
Original = Original.dropna()

# %%
IncidentCount = Original.groupby('State')[['Incident Date']].count()
IncidentCount = IncidentCount.rename(columns={"Incident Date": "# of Incidents"})

# %%
DFT = Original.drop(columns={"Unnamed: 0", "Incident Date", "City Or County", "Address"})

# %%
DFTS = DFT.groupby('State')[['# Killed','# Injured']].sum()

# %%
DFTS.head()
# Out:
#              # Killed  # Injured
# State
# Alabama          17.0       47.0
# Arizona           7.0       26.0
# Arkansas          3.0       20.0
# Connecticut       1.0       12.0
# Delaware          0.0       10.0

# %%
LawsandRegistration = pd.read_csv("GunLawsandRegistration.csv")

# %%
LawsandRegistration1 = LawsandRegistration.drop(columns="Unnamed: 0")
LawsandRegistration1.head()
# Out:
#         State  firearmRegRequired  permitReqToCarry  permitReqToPurchase  \
# 0  Washington                True              True                False
# 1    New York                True              True                 True
# 2  New Jersey                True              True                 True
# 3    Michigan                True              True                False
# 4    Maryland                True              True                 True
#
#   openCarryLegal Number of Registered Weapons
# 0           True                      119,829
# 1          False                       82,917
# 2          False                       90,217
# 3           True                       83,355
# 4           True                      128,289

# %%
Merge = pd.merge(IncidentCount, DFTS, how="left", on="State")
Merge.head()
# Out:
#              # of Incidents  # Killed  # Injured
# State
# Alabama                  12      17.0       47.0
# Arizona                   6       7.0       26.0
# Arkansas                  5       3.0       20.0
# Connecticut               3       1.0       12.0
# Delaware                  2       0.0       10.0

# %%
FinalMerge = pd.merge(Merge, LawsandRegistration1, how="left", on="State")
FinalMerge.head()
# Out:
#          State  # of Incidents  # Killed  # Injured  firearmRegRequired  \
# 0      Alabama              12      17.0       47.0               False
# 1      Arizona               6       7.0       26.0               False
# 2     Arkansas               5       3.0       20.0               False
# 3  Connecticut               3       1.0       12.0                True
# 4     Delaware               2       0.0       10.0               False
#
#    permitReqToCarry  permitReqToPurchase openCarryLegal  \
# 0              True                False           True
# 1             False                False           True
# 2             False                False           True
# 3              True                 True           True
# 4              True                False           True
#
#   Number of Registered Weapons
# 0                      168,265
# 1                      204,817
# 2                      108,801
# 3                       74,877
# 4                        5,281

# %%
FinalC = FinalMerge.rename(columns={"firearmRegRequired":"Fire Arm Registration Required","permitReqToCarry":"Permit to Carry Required","permitReqToPurchase":"Permit to Purchase Required",  "openCarryLegal":"Open Carry is Legal",  })

# %%
FinalClean = FinalC.rename(columns={"# of Incidents": "Mass Shootings 2019", "# Killed": "Total Killed", "# Injured": "Total Injured"})

# %%
FinalClean.head()
# Out:
#          State  Mass Shootings 2019  Total Killed  Total Injured  \
# 0      Alabama                   12          17.0           47.0
# 1      Arizona                    6           7.0           26.0
# 2     Arkansas                    5           3.0           20.0
# 3  Connecticut                    3           1.0           12.0
# 4     Delaware                    2           0.0           10.0
#
#    Fire Arm Registration Required  Permit to Carry Required  \
# 0                           False                      True
# 1                           False                     False
# 2                           False                     False
# 3                            True                      True
# 4                           False                      True
#
#    Permit to Purchase Required Open Carry is Legal  \
# 0                        False                True
# 1                        False                True
# 2                        False                True
# 3                         True                True
# 4                        False                True
#
#   Number of Registered Weapons
# 0                      168,265
# 1                      204,817
# 2                      108,801
# 3                       74,877
# 4                        5,281

# %%
Final = FinalClean.set_index("State")
Final

Final.to_csv("FinalClean.csv")

# %%
SQLReady = Final.rename(columns={"Mass Shootings 2019":"Mass_Shootings_2019", "Total Killed": "Total_Killed", "Total Injured":"Total_Injured", "Fire Arm Registration Required": "Fire_Arm_Registration_Required", "Permit to Carry Required": "Permit_to_Carry_Required", "Permit to Purchase Required":"Permit_to_Purchase_Required", "Open Carry is Legal":"Open_Carry_is_Legal", "Number of Registered Weapons", "Number_of_Registered_Weapons"})
# Out:
#                 Mass Shootings 2019  Total Killed  Total Injured  \
# State
# Alabama                          12          17.0           47.0
# Arizona                           6           7.0           26.0
# Arkansas                          5           3.0           20.0
# Connecticut                       3           1.0           12.0
# Delaware                          2           0.0           10.0
# Florida                          15          20.0           54.0
# Georgia                          19          16.0           74.0
# Illinois                         41          28.0          182.0
# Indiana                          10           6.0           49.0
# Iowa                              3           3.0           11.0
# Kansas                            4           5.0           16.0
# Kentucky                          5           6.0           18.0
# Louisiana                        26          20.0          106.0
# Maryland                         21          12.0           85.0
# Massachusetts                     5           7.0           17.0
# Michigan                          9           8.0           35.0
# Minnesota                         2           1.0           12.0
# Mississippi                       6           8.0           21.0
# Missouri                         18          20.0           60.0
# Montana                           2           5.0            4.0
# Nebraska                          1           0.0            4.0
# Nevada                            3           1.0           12.0
# New Jersey                       11          12.0           47.0
# New Mexico                        5           8.0           17.0
# New York                          9           7.0           43.0
# North Carolina                   11          13.0           40.0
# Ohio                             14          20.0           61.0
# Oklahoma                          4           5.0           12.0
# Oregon                            1           0.0            5.0
# Pennsylvania                     19          13.0           84.0
# South Carolina                   10          10.0           42.0
# Tennessee                         7           3.0           31.0
# Texas                            31          72.0          147.0
# Virginia                         10          21.0           41.0
# Washington                        4           8.0           12.0
# Wisconsin                         3           5.0           10.0
# Wyoming                           1           2.0            2.0
#
#                 Fire Arm Registration Required  Permit to Carry Required  \
# State
# Alabama                                  False                      True
# Arizona                                  False                     False
# Arkansas                                 False                     False
# Connecticut                               True                      True
# Delaware                                 False                      True
# Florida                                  False                      True
# Georgia                                  False                      True
# Illinois                                 False                      True
# Indiana                                  False                      True
# Iowa                                     False                      True
# Kansas                                   False                     False
# Kentucky                                 False                      True
# Louisiana                                False                      True
# Maryland                                  True                      True
# Massachusetts                            False                      True
# Michigan                                  True                      True
# Minnesota                                False                      True
# Mississippi                              False                     False
# Missouri                                 False                     False
# Montana                                  False                     False
# Nebraska                                 False                      True
# Nevada                                   False                      True
# New Jersey                                True                      True
# New Mexico                               False                      True
# New York                                  True                      True
# North Carolina                           False                      True
# Ohio                                     False                      True
# Oklahoma                                 False                      True
# Oregon                                   False                      True
# Pennsylvania                             False                      True
# South Carolina                           False                      True
# Tennessee                                False                      True
# Texas                                    False                      True
# Virginia                                 False                      True
# Washington                                True                      True
# Wisconsin                                False                      True
# Wyoming                                  False                     False
#
#                 Permit to Purchase Required Open Carry is Legal  \
# State
# Alabama                               False                True
# Arizona                               False                True
# Arkansas                              False                True
# Connecticut                            True                True
# Delaware                              False                True
# Florida                               False               False
# Georgia                               False                True
# Illinois                               True               False
# Indiana                               False                True
# Iowa                                   True                True
# Kansas                                False                True
# Kentucky                              False                True
# Louisiana                             False                True
# Maryland                               True                True
# Massachusetts                          True                True
# Michigan                              False                True
# Minnesota                              True                True
# Mississippi                           False                True
# Missouri                              False                True
# Montana                               False                True
# Nebraska                               True                True
# Nevada                                False                True
# New Jersey                             True               False
# New Mexico                            False                True
# New York                               True               False
# North Carolina                         True                True
# Ohio                                  False                True
# Oklahoma                              False                True
# Oregon                                False                True
# Pennsylvania                          False                True
# South Carolina                        False               False
# Tennessee                             False                True
# Texas                                 False                True
# Virginia                              False                True
# Washington                            False                True
# Wisconsin                             False                True
# Wyoming                               False                True
#
#                Number of Registered Weapons
# State
# Alabama                             168,265
# Arizona                             204,817
# Arkansas                            108,801
# Connecticut                          74,877
# Delaware                              5,281
# Florida                             432,581
# Georgia                             225,993
# Illinois                            147,698
# Indiana                             133,594
# Iowa                                 36,540
# Kansas                               54,409
# Kentucky                             93,719
# Louisiana                           116,398
# Maryland                            128,289
# Massachusetts                        39,886
# Michigan                             83,355
# Minnesota                            98,585
# Mississippi                          52,346
# Missouri                             88,270
# Montana                              23,476
# Nebraska                             29,753
# Nevada                               96,822
# New Jersey                           90,217
# New Mexico                          105,836
# New York                             82,917
# North Carolina                      181,209
# Ohio                                175,819
# Oklahoma                             83,112
# Oregon                               74,722
# Pennsylvania                        271,427
# South Carolina                       99,283
# Tennessee                           121,140
# Texas                               725,368
# Virginia                            356,963
# Washington                          119,829
# Wisconsin                            79,639
# Wyoming                             134,050
